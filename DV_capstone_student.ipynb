# %% [markdown]
# <a href="https://colab.research.google.com/github/glcn35/MATPLOTLIB-SEABORN/blob/main/DV_capstone_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.
#
#
# Veri Görselleştirme Derslerinin en önemli projesi olan 'Bisiklet Talep Görselleştirme Projesi'ne hoş geldiniz. Bildiğiniz gibi son zamanlarda şehir içi kısa mesafeli yolculuklar için motorlu toplu taşıma veya özel araçlara alternatif olarak bisiklete ücretsiz veya uygun fiyata ulaşım sağlandı. Böylece trafik sıkışıklığının, gürültünün ve hava kirliliğinin azaltılması hedefleniyor.
#
# Bu projenin amacı, Londra bisiklet paylaşımlarının tarihsel verilerini görselleştirme araçlarıyla göstererek verilerdeki mevcut kalıpları ortaya çıkarmaktır.
#
# Bu, bir makine öğrenimi modeli kurmadan önce verileri EDA sürecinin bir parçası olarak röntgen çekmemize olanak tanır.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Özellikleri
# zaman damgası - verileri gruplamak için zaman damgası alanı
# cnt - yeni bir bisiklet paylaşımlarının sayısı
# t1 - C cinsinden gerçek sıcaklık
# t2 - C cinsinden sıcaklık 'hissediyor'
# hum - yüzde olarak nem
# wind_speed - km/saat cinsinden rüzgar hızı
# weather_code - hava durumu kategorisi
# is_holiday - boole alanı - 1 tatil / 0 tatil dışı
# is_weekend - boole alanı - gün hafta sonu ise 1
# mevsim - kategori alanı meteorolojik mevsimler: 0-bahar ; 1-yaz; 2-düşme; 3-kış.
# 'hava_kodu' kategori açıklaması:
#
# 1 = Temizle ; çoğunlukla açık ama yakınlarda pus/sis/sis/sis parçaları olan bazı değerler var
# 2 = dağınık bulutlar / birkaç bulut
# 3 = Kırık bulutlar
# 4 = Bulutlu
# 7 = Yağmur/ hafif Yağmur duşu/ Hafif yağmur
# 10 = fırtınalı yağmur
# 26 = kar yağışı
# 94 = Donan Sis
# Başlangıçta verileri keşfetme görevi her zamanki gibi sizi bekliyor olacak. Özellikleri tanıyın, eksik değerleri, aykırı değerleri tespit edin vb. Verileri farklı zaman dilimlerinde çeşitli açılardan gözden geçirin. Örneğin, bisiklet paylaşımlarının haftanın günlerine göre dağılımını görselleştirin. Bu grafik ile insanların davranışlarının günlük olarak nasıl değiştiğini kolayca gözlemleyebilecek ve çıkarımlarda bulunabileceksiniz. Aynı şekilde saatlik, aylık, mevsimsel vb. analizler de yapabilirsiniz. Ek olarak, bir ısı haritası ile değişkenlerin korelasyonunu analiz edebilirsiniz.
#
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df=pd.read_csv("/content/sample_data/store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df["is_holiday"].value_counts()
# Out:
# 0.0    17030
# 1.0      384
# Name: is_holiday, dtype: int64

# %%
df["season"].value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
df["weather_code"].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull()["t1"].value_counts()
# Out:
# False    17414
# Name: t1, dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
#
#
# 4.Çeşitli ayrık özelliklerin dağılımını (Mevsim, bayram, hafta sonu ve hava kodu) çizin

# %%
df["season"].value_counts().plot.bar();

# %%
df["season"].value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
a=df["season"].value_counts().index
a
# Out:
# Float64Index([0.0, 1.0, 3.0, 2.0], dtype='float64')

# %%
b=df["season"].value_counts().values
b
# Out:
# array([4394, 4387, 4330, 4303])

# %%
plt.bar(a,b,color="byrg")
plt.xlabel("season")
plt.ylabel("count");

# %%
sns.countplot(x="season",data=df)

# %%
# is_holiday
fig,ax=plt.subplots()
sns.countplot("is_holiday",data=df)
for p in ax.patches:
  ax.annotate(p.get_height(), (p.get_x()+0.3, p.get_height()+10));

# %%
# is_weekend
sns.countplot("is_weekend",data=df);

# %%
# weather_code
fig,ax=plt.subplots()
sns.countplot("weather_code",data=df)
for p in ax.patches:
  ax.annotate(p.get_height(), (p.get_x()+0.3, p.get_height()+10));

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.
#
# 5. Her bir değişkenin veri tipine bakın, zaman damgasını tipe dönüştürün ve indeks olarak ayarlayın

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %%
df["timestamp"]=pd.to_datetime(df.timestamp)
df["timestamp"]
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
df.set_index("timestamp", inplace=True)

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  is_holiday  is_weekend  season
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5  ...         0.0         1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5  ...         0.0         1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0  ...         0.0         1.0     3.0
#
# [5 rows x 9 columns]

# %%
df.index.max()
# Out:
# Timestamp('2017-01-03 23:00:00')

# %%
df.index.min()
# Out:
# Timestamp('2015-01-04 00:00:00')

# %%
df.index.max()-df.index.min()
# Out:
# Timedelta('730 days 23:00:00')

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
df["day_of_week"]=df.index.dayofweek
df["day_of_week"]
# Out:
# timestamp
# 2015-01-04 00:00:00    6
# 2015-01-04 01:00:00    6
# 2015-01-04 02:00:00    6
# 2015-01-04 03:00:00    6
# 2015-01-04 04:00:00    6
#                       ..
# 2017-01-03 19:00:00    1
# 2017-01-03 20:00:00    1
# 2017-01-03 21:00:00    1
# 2017-01-03 22:00:00    1
# 2017-01-03 23:00:00    1
# Name: day_of_week, Length: 17414, dtype: int64

# %%
df["day_of_month"]=df.index.day
df["day_of_month"]
# Out:
# timestamp
# 2015-01-04 00:00:00    4
# 2015-01-04 01:00:00    4
# 2015-01-04 02:00:00    4
# 2015-01-04 03:00:00    4
# 2015-01-04 04:00:00    4
#                       ..
# 2017-01-03 19:00:00    3
# 2017-01-03 20:00:00    3
# 2017-01-03 21:00:00    3
# 2017-01-03 22:00:00    3
# 2017-01-03 23:00:00    3
# Name: day_of_month, Length: 17414, dtype: int64

# %%
df["month"]=df.index.month
df["month"]
# Out:
# timestamp
# 2015-01-04 00:00:00    1
# 2015-01-04 01:00:00    1
# 2015-01-04 02:00:00    1
# 2015-01-04 03:00:00    1
# 2015-01-04 04:00:00    1
#                       ..
# 2017-01-03 19:00:00    1
# 2017-01-03 20:00:00    1
# 2017-01-03 21:00:00    1
# 2017-01-03 22:00:00    1
# 2017-01-03 23:00:00    1
# Name: month, Length: 17414, dtype: int64

# %%
df["year"]=df.index.year
df["year"]
# Out:
# timestamp
# 2015-01-04 00:00:00    2015
# 2015-01-04 01:00:00    2015
# 2015-01-04 02:00:00    2015
# 2015-01-04 03:00:00    2015
# 2015-01-04 04:00:00    2015
#                        ...
# 2017-01-03 19:00:00    2017
# 2017-01-03 20:00:00    2017
# 2017-01-03 21:00:00    2017
# 2017-01-03 22:00:00    2017
# 2017-01-03 23:00:00    2017
# Name: year, Length: 17414, dtype: int64

# %%
df["year_month"]=df.index.strftime("%Y-%m")
df["year_month"]
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-01
# 2015-01-04 01:00:00    2015-01
# 2015-01-04 02:00:00    2015-01
# 2015-01-04 03:00:00    2015-01
# 2015-01-04 04:00:00    2015-01
#                         ...
# 2017-01-03 19:00:00    2017-01
# 2017-01-03 20:00:00    2017-01
# 2017-01-03 21:00:00    2017-01
# 2017-01-03 22:00:00    2017-01
# 2017-01-03 23:00:00    2017-01
# Name: year_month, Length: 17414, dtype: object

# %%
df["hour"]=df.index.hour
df["hour"]
# Out:
# timestamp
# 2015-01-04 00:00:00     0
# 2015-01-04 01:00:00     1
# 2015-01-04 02:00:00     2
# 2015-01-04 03:00:00     3
# 2015-01-04 04:00:00     4
#                        ..
# 2017-01-03 19:00:00    19
# 2017-01-03 20:00:00    20
# 2017-01-03 21:00:00    21
# 2017-01-03 22:00:00    22
# 2017-01-03 23:00:00    23
# Name: hour, Length: 17414, dtype: int64

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  ...  month  year  year_month  hour
# timestamp                                  ...
# 2015-01-04 00:00:00  182  3.0  2.0   93.0  ...      1  2015     2015-01     0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0  ...      1  2015     2015-01     1
# 2015-01-04 02:00:00  134  2.5  2.5   96.5  ...      1  2015     2015-01     2
# 2015-01-04 03:00:00   72  2.0  2.0  100.0  ...      1  2015     2015-01     3
# 2015-01-04 04:00:00   47  2.0  0.0   93.0  ...      1  2015     2015-01     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   day_of_week   17414 non-null  int64
#  10  day_of_month  17414 non-null  int64
#  11  month         17414 non-null  int64
#  12  year          17414 non-null  int64
#  13  year_month    17414 non-null  object
#  14  hour          17414 non-null  int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 2.1+ MB

# %%
fig, ax = plt.subplots(figsize=(15, 9))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")

# %%
df.corr()
# Out:
#                    cnt        t1        t2  ...     month      year      hour
# cnt           1.000000  0.388798  0.369035  ...  0.063757  0.010046  0.324423
# t1            0.388798  1.000000  0.988344  ...  0.332712 -0.037959  0.168708
# t2            0.369035  0.988344  1.000000  ...  0.368366 -0.044972  0.153956
# hum          -0.462901 -0.447781 -0.403495  ...  0.113149  0.072443 -0.295653
# wind_speed    0.116295  0.145471  0.088409  ... -0.086383 -0.094739  0.141792
# weather_code -0.166633 -0.097114 -0.098385  ... -0.033253 -0.009234 -0.041786
# is_holiday   -0.051698 -0.042233 -0.040051  ... -0.011511  0.034631 -0.000288
# is_weekend   -0.096499 -0.005342 -0.008510  ... -0.005406  0.003049  0.001803
# season       -0.116180 -0.285851 -0.285900  ...  0.203249  0.024400  0.000006
# day_of_week  -0.068688 -0.002317 -0.006824  ... -0.001080 -0.002876  0.001834
# day_of_month -0.017887  0.005072  0.006791  ...  0.012614 -0.021935 -0.000310
# ...

# %%
corr=df.corr()
corr2=corr['cnt'].sort_values(ascending=False)

# %%
fig, ax = plt.subplots(figsize=(2, 6))
sns.heatmap(pd.DataFrame(corr2),
            cmap="BrBG",annot=True)

# %%
fig, ax = plt.subplots(figsize=(2, 6))
sns.heatmap(data=df.corr()[["cnt"]].sort_values("cnt",ascending=False), vmin=-1, vmax=1, annot=True, center=0.6 );

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
df.corr()["cnt"].sort_values().plot(kind="barh",figsize=(10,6));

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x="timestamp", y="cnt", data=df);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
plt.figure(figsize=(20, 5))
sns.lineplot(x="year_month", y="cnt", data=df, ci=None)
plt.ticklabel_format(style="plain",axis="y")  #e üzeri değrler filan çıktığında ondan kurtulmata yarar
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x="month", y="cnt", data=df);

# %%
plt.figure(figsize=(15, 5))
sns.pointplot(x="month", y="cnt", data=df);

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="month", y="cnt", data=df);  #ci =60 değerini seçebiliriz,değiştirebliriz. çubuk boyu=ci

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(20, 5))
sns.lineplot(x="hour", y="cnt", data=df, hue="is_holiday")

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(20, 5))
sns.lineplot(x="hour", y="cnt", data=df, hue="season");

# %%
# with pointplot
fig,(ax1, ax2, ax3, ax4)= plt.subplots(nrows=4, figsize=(18,15)  )

sns.pointplot(data=df, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=df, x='hour', y='cnt', hue='season', ax=ax2)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_weekend', ax=ax3)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_holiday', ax=ax4);

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
sns.barplot(x="day_of_week", y="cnt", hue="is_weekend", data=df);

# %%
# with pointplot

# %%
fig,ax=plt.subplots(2,1,figsize=(15,5))
ax[0]=sns.pointplot(x="day_of_week", y="cnt", data=df)
ax[1]=sns.pointplot(x="day_of_week", y="cnt", data=df,hue="season")

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
df.groupby("day_of_month")[["cnt"]].mean().apply(lambda x:round(x)).T
# Out:
# day_of_month      1       2       3       4   ...      28      29      30     31
# cnt           1077.0  1088.0  1128.0  1144.0  ...  1063.0  1080.0  1156.0  968.0
#
# [1 rows x 31 columns]

# %%
plt.figure(figsize=(15, 5))
sns.lineplot(x='day_of_month', y='cnt',data=df)
df.groupby("day_of_month")[["cnt"]].mean().apply(lambda x:round(x)).T
# Out:
# day_of_month      1       2       3       4   ...      28      29      30     31
# cnt           1077.0  1088.0  1128.0  1144.0  ...  1063.0  1080.0  1156.0  968.0
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="year",y="cnt",data=df);

# %%
# with barplot
sns.barplot(x="season",y="cnt", data = df[df["is_holiday"]==1]);

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(5, 5))
explode=(0, 0.1)
ax.pie(x=df.is_weekend.value_counts().values,
       labels=['weekday', 'weekend'],
       autopct='%.1f%%',
       explode=explode
       )
plt.show()

# %%
# with countplot
fig, ax = plt.subplots(figsize=(7, 5))
ax = sns.countplot(x='is_weekend',data=df)
for bar in ax.patches:
        ax.annotate("%" + str(round(100*bar.get_height()/len(df), 1)) + ' - ' + str(bar.get_height() ),
                    (bar.get_x()+0.2 , bar.get_height()+10),
                    size=12)

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
sns.countplot(x="weather_code",data=df);

# %%
# with catplot
sns.catplot(x="weather_code", data=df, col= "season", kind= "count");

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 4))
sns.countplot(data=df.loc[df['season']==0.0], x ='weather_code',ax=ax[0])
sns.countplot(data=df.loc[df['season']==1.0], x ='weather_code', ax=ax[1])
sns.countplot(data=df.loc[df['season']==2.0], x ='weather_code', ax=ax[2])
sns.countplot(data=df.loc[df['season']==3.0], x ='weather_code', ax=ax[3])
plt.tight_layout;

# %%
sns.catplot(x="weather_code", data=df, hue= "season", kind= "count");

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
